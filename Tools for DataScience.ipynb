# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __priyanka poojari__
#
# Data scientist

# %% [markdown]
# *I am interested in data science because it is a very evolving field and solves major problems in companies*

# %% [markdown]
# ### This code performs multiplication

# %%
4*3
# Out:
# 12

# %% [markdown]
# ~~Done~~
# 1. choose numbers
# 2. multipy numbers
# 3. get answer
#
# [I'm a hyperlink to google site](https://www.google.com)
